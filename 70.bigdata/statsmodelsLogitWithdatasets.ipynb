# %%
from sklearn import datasets
iris_dataset = datasets.load_iris()
print(iris_dataset)

# %%
train_x = iris_dataset.data
train_y = iris_dataset.target
train_x.shape, train_y.shape
# Out:
# ((150, 4), (150,))

# %%
import statsmodels.api as sm
# sm_constant = sm.add_constant(train_x)
logit_model=sm.MNLogit(train_y,train_x)
result=logit_model.fit()
print(result.summary())
# Out:
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.072266
#          Iterations: 35
#                           MNLogit Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  150
# Model:                        MNLogit   Df Residuals:                      142
# Method:                           MLE   Df Model:                            6
# Date:                Thu, 21 May 2020   Pseudo R-squ.:                  0.9342
# Time:                        02:05:45   Log-Likelihood:                -10.840
# converged:                      False   LL-Null:                       -164.79
# Covariance Type:            nonrobust   LLR p-value:                 1.655e-63
# ==============================================================================
#        y=1       coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1            -6.2825   6.46e+04  -9.72e-05      1.000   -1.27e+05    1.27e+05
# x2           -10.3450   1.08e+05   -9.6e-05      1.000   -2.11e+05    2.11e+05
# x3            19.5419      2e+05   9.77e-05      1.000   -3.92e+05    3.92e+05
# x4            19.6131   4.09e+05    4.8e-05      1.000   -8.01e+05    8.01e+05
# ------------------------------------------------------------------------------
#        y=2       coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1           -12.6102   6.46e+04     -0.000      1.000   -1.27e+05    1.27e+05
# x2           -16.9631   1.08e+05     -0.000      1.000   -2.11e+05    2.11e+05
# x3            27.9757      2e+05      0.000      1.000   -3.92e+05    3.92e+05
# x4            29.8956   4.09e+05   7.32e-05      1.000   -8.01e+05    8.01e+05
# ==============================================================================
# /usr/local/lib/python3.6/dist-packages/statsmodels/base/model.py:512: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
