# %% [markdown]
# # 파이프 라인

# %%
from sklearn import datasets
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %%
raw_boston = datasets.load_boston()

X = raw_boston.data
y = raw_boston.target

# 트레이닝 / 테스트 데이터 분할
X_tn, X_te, y_tn, y_te = train_test_split(X,y,random_state=7)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function load_boston is deprecated; `load_boston` is deprecated in 1.0 and will be removed in 1.2.
#
#     The Boston housing prices dataset has an ethical problem. You can refer to
#     the documentation of this function for further details.
#
#     The scikit-learn maintainers therefore strongly discourage the use of this
#     dataset unless the purpose of the code is to study and educate about
#     ethical issues in data science and machine learning.
#
#     In this special case, you can fetch the dataset from the original
#     source::
#
#         import pandas as pd
#         import numpy as np
#
#
#         data_url = "http://lib.stat.cmu.edu/datasets/boston"
#         raw_df = pd.read_csv(data_url, sep="\s+", skiprows=22, header=None)
#         data = np.hstack([raw_df.values[::2, :], raw_df.values[1::2, :2]])
#         target = raw_df.values[1::2, 2]
#
# ...

# %%
import pandas as pd
X_tn_df = pd.DataFrame(X_tn)
X_tn_df.describe()
# Out:
#                0           1           2           3           4           5   \
# count  379.000000  379.000000  379.000000  379.000000  379.000000  379.000000
# mean     3.419115   11.493404   11.010106    0.071240    0.550740    6.270749
# std      8.357309   23.516528    6.941068    0.257566    0.113699    0.718699
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.079640    0.000000    5.040000    0.000000    0.448000    5.876500
# 50%      0.224380    0.000000    8.560000    0.000000    0.532000    6.182000
# 75%      2.542505   12.500000   18.100000    0.000000    0.624000    6.617000
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.725000
#
#                6           7           8           9           10          11  \
# count  379.000000  379.000000  379.000000  379.000000  379.000000  379.000000
# mean    68.535356    3.791384    9.079156  400.775726   18.375198  360.610158
# ...

# %%
std_scale = StandardScaler()
X_tn_std = std_scale.fit_transform(X_tn_df)
X_tn_std_df = pd.DataFrame(X_tn_std)
X_tn_std_df.describe()
# Out:
#                  0             1             2             3             4   \
# count  3.790000e+02  3.790000e+02  3.790000e+02  3.790000e+02  3.790000e+02
# mean   2.312721e-16  1.652152e-16  2.958642e-15 -3.151979e-16 -5.086813e-15
# std    1.001322e+00  1.001322e+00  1.001322e+00  1.001322e+00  1.001322e+00
# min   -4.089004e-01 -4.893833e-01 -1.521963e+00 -2.769559e-01 -1.459644e+00
# 25%   -4.001156e-01 -4.893833e-01 -8.612503e-01 -2.769559e-01 -9.048147e-01
# 50%   -3.827737e-01 -4.893833e-01 -3.534534e-01 -2.769559e-01 -1.650428e-01
# 75%   -1.050301e-01  4.286036e-02  1.022792e+00 -2.769559e-01  6.451835e-01
# max    1.025093e+01  3.768566e+00  2.413463e+00  3.610684e+00  2.820465e+00
#
#                  5             6             7             8             9   \
# count  3.790000e+02  3.790000e+02  3.790000e+02  3.790000e+02  3.790000e+02
# mean  -1.728316e-15 -8.934512e-16  8.974059e-16 -1.321136e-16 -1.737104e-16
# ...

# %%
# 표준화 스케일링
# 학습
clf_linear =  LinearRegression()
clf_linear.fit(X_tn_std_df, y_tn)

pred_linear = clf_linear.predict(X_tn)
print(mean_squared_error(y_tn, pred_linear))

pred_linear = clf_linear.predict(X_tn_std_df)
print(mean_squared_error(y_tn, pred_linear))

# 예측
X_te_std  = std_scale.transform(X_te)
X_te_std_df = pd.DataFrame(X_te_std)
pred_linear = clf_linear.predict(X_te_std_df)

# 평가
mean_squared_error(y_te, pred_linear)
# Out:
# 322174.7885360818
# 20.266043144184472
# 29.515137790197567

# %%
# 트레이닝 / 테스트 데이터 분할
X_tn, X_te, y_tn, y_te = train_test_split(X,y,random_state=7)

# 파이프라인
linear_pipline = Pipeline([
    ('scaler',StandardScaler()), 
    ('linear_regression', LinearRegression()) 
])

# 학습
linear_pipline.fit(X_tn_std_df, y_tn)

# 예측
pred_linear = linear_pipline.predict(X_te_std_df)

# 평가
mean_squared_error(y_te, pred_linear)
# Out:
# 29.51513779019759

# %%
X_te_std  = std_scale.transform(X_te[:,])

# %%
X_te_std_df = pd.DataFrame(X_te_std)

# %%
# 학습
linear_pipline.fit(X_tn_std_df, y_tn)

# 예측
pred_linear = linear_pipline.predict(X_te_std_df)

# 평가
mean_squared_error(y_te, pred_linear)
# Out:
# 29.51513779019759
